# %%
from SINDyFunctions import *
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat

# %% [markdown]
# ### LV2

# %%
data = loadmat("ResultsLog/LV_poly2.mat")
plotResult(data)

# %% [markdown]
# ### LV5

# %%
data = loadmat("ResultsLog/LV_poly5.mat")
plotResult(data)

# %% [markdown]
# ### Lorenz 2

# %%
data = loadmat("ResultsLog/Lorenz_poly2.mat")
plotResult(data)

# %% [markdown]
# ### Lorenz 5

# %%
data = loadmat("ResultsLog/Lorenz_poly5.mat")
plotResult(data)

# %% [markdown]
# ### VDP 5

# %%
data = loadmat("ResultsLog/VDP_poly5.mat")
plotResult(data)

# %% [markdown]
# ### Hyper Lorenz 3

# %%
data = loadmat("ResultsLog/VDP_poly3.mat")
plotResult(data)

# %% [markdown]
# ### Hyper Jha 3

# %%
data = loadmat("ResultsLog/hyperLorenz_poly3.mat")
plotResult(data)

# %%
data = loadmat("ResultsLog/hyperJha_poly3.mat")
plotResult(data)
