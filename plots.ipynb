# %%
from SINDyFunctions import *
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat

# %% [markdown]
# ### LV2

# %%
data = loadmat("ResultsLog/LV_poly2.mat")
plotResult(data,save_path="LV2.pdf")

# %% [markdown]
# ### LV5

# %%
data = loadmat("ResultsLog/LV_poly5.mat")
plotResult(data,save_path="LV5.pdf")

# %% [markdown]
# ### Lorenz 2

# %%
data = loadmat("ResultsLog/Lorenz_poly2.mat")
plotResult(data,save_path="Lorenz2.pdf")

# %% [markdown]
# ### Lorenz 5

# %%
data = loadmat("ResultsLog/Lorenz_poly5.mat")
plotResult(data,save_path="Lorenz5.pdf")

# %% [markdown]
# ### Hyper Lorenz 3

# %%
data = loadmat("ResultsLog/hyperLorenz_poly3.mat")
plotResult(data,save_path="HyperLorenz3.pdf")

# %% [markdown]
# ### Hyper Jha 3

# %%
data = loadmat("ResultsLog/hyperJha_poly3.mat")
plotResult(data,save_path="HyperJha3.pdf")

# %% [markdown]
# ### Test Function Numbers (FFT-Selected)

# %%
data = loadmat("ResultsLog/Lorenz_poly2_funcNum.mat")
plotResult_funcNum(data,save_path="Lorenz2_funcNum.pdf")

# %% [markdown]
# ### Lorenz 2 PySINDy

# %%
data = loadmat("ResultsLog/Lorenz_poly2.mat")
data_ps = loadmat("Lorenz_poly2_ps.mat")
plotResult(data,data_ps=data_ps,save_path="Lorenz2_ps.pdf")

# %% [markdown]
# ### Lorenz 5 PySINDy

# %%
data = loadmat("ResultsLog/Lorenz_poly5.mat")
data_ps = loadmat("Lorenz_poly5_ps.mat")
plotResult(data,data_ps=data_ps,save_path="Lorenz5_ps.pdf")

# %% [markdown]
# ### LV 2 PySINDy

# %%
data = loadmat("ResultsLog/LV_poly2.mat")
data_ps = loadmat("ResultsLog/LV_poly2_ps.mat")
plotResult(data,data_ps=data_ps,save_path="LV2_ps.pdf")

# %% [markdown]
# ### Hyper Lorenz 3 PySINDy

# %%
data = loadmat("ResultsLog/hyperLorenz_poly3.mat")
data_ps = loadmat("hyperLorenz_poly3_ps.mat")
plotResult(data,data_ps=data_ps,save_path="HyperLorenz3_ps.pdf")

# %% [markdown]
# ### Hyper Jha 3 PySINDy

# %%
data = loadmat("ResultsLog/hyperJha_poly3.mat")
data_ps = loadmat("hyperJha_poly3_ps.mat")
plotResult(data,data_ps=data_ps,save_path="HyperJha3_ps.pdf")
# Out:
# Plot saved to HyperJha3_ps.pdf

# %% [markdown]
# ### Hyper Lorenz 2 PySINDy

# %%
data = loadmat("ResultsLog/hyperLorenz_poly2.mat")
data_ps = loadmat("hyperLorenz_poly2_ps.mat")
plotResult(data,data_ps=data_ps,save_path="HyperLorenz2_ps.pdf")
# Out:
# Plot saved to HyperLorenz2_ps.pdf

# %% [markdown]
# ### Hyper Jha 2 PySINDy

# %%
data = loadmat("ResultsLog/hyperJha_poly2.mat")
data_ps = loadmat("hyperJha_poly2_ps.mat")
plotResult(data,data_ps=data_ps,save_path="HyperJha2_ps.pdf")
# Out:
# Plot saved to HyperJha2_ps.pdf

# %% [markdown]
# ### Bandwidth

# %%
data = loadmat("ResultsLog/Lorenz_poly2_bandwidth.mat")
plotResult_bandwidth(data,save_path="Lorenz2_bandwidth.pdf")
